# %%
import matplotlib
from matplotlib import pyplot as plt
from pylab import *
import ase
from ase.visualize import view
from ase.lattice import HEX2D
import numpy as np

import sisl 
import sisl.viz
    
from tqdm import tqdm   
from SE_utils import *
from PDOs_utils import *

# %%
HOME_DIR='./'

# %% [markdown]
# # Graphene Band Structure

# %%
bond=1.43
C = sisl.Atom(6, R = bond + 0.01)
# Create graphene unit-cell
gr = sisl.geom.graphene(bond, C)

# Create the tight-binding Hamiltonian
Ham0 = sisl.Hamiltonian(gr)
R = [0.1 * bond, bond + 0.01]

for ia in gr:
    idx_a = gr.close(ia, R)
    # On-site
    Ham0[ia, idx_a[0]] = 0.
    # Nearest neighbour hopping
    Ham0[ia, idx_a[1]] = -2.7

# %%
H0_DFT=sisl.get_sile(HOME_DIR+'Graphene/siesta.fdf').read_hamiltonian()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 H0_DFT=sisl.get_sile(HOME_DIR+'Graphene/siesta.fdf').read_hamiltonian()
#
# File ~/projects/QTM-ML/.venv/lib/python3.13/site-packages/sisl/io/siesta/fdf.py:2278, in fdfSileSiesta.read_hamiltonian(self, *args, **kwargs)
#    2276 order = _parse_order(kwargs.pop("order", None), ["nc", "TSHS", "HSX"])
#    2277 for f in order:
# -> 2278     H = getattr(self, f"_r_hamiltonian_{f.lower()}")(*args, **kwargs)
#    2279     if H is not None:
#    2280         return H
#
# File ~/projects/QTM-ML/.venv/lib/python3.13/site-packages/sisl/io/siesta/fdf.py:2285, in fdfSileSiesta._r_hamiltonian_nc(self, *args, **kwargs)
#    2283 def _r_hamiltonian_nc(self, *args, **kwargs):
#    2284     """Read Hamiltonian from the nc file"""
# -> 2285     f = self.dir_file(self.get("SystemLabel", default="siesta") + ".nc")
#    2286     _track_file(self._r_hamiltonian_nc, f, inputs=[("CDF.Save", "True")])
#    2287     if f.is_file():
#
# File ~/projects/QTM-ML/.venv/lib/python3.13/site-packages/sisl/io/sile.py:789, in sile_fh_open.<locals>._wrapper.<locals>.pre_open(self, *args, **kwargs)
#     787 if hasattr(self, "fh"):
#     788     return func(self, *args, **kwargs)
# --> 789 with self:
#     790     reset(self)
#     791     return func(self, *args, **kwargs)
#
# File ~/projects/QTM-ML/.venv/lib/python3.13/site-packages/sisl/io/sile.py:1364, in Sile.__enter__(self)
#    1362 def __enter__(self):
#    1363     """Opens the output file and returns it self"""
# -> 1364     self._open()
#    1365     return self
#
# File ~/projects/QTM-ML/.venv/lib/python3.13/site-packages/sisl/io/sile.py:1355, in Sile._open(self)
#    1353             self.fh = gzip.open(str(self.file), mode=self._mode)
#    1354     else:
# -> 1355         self.fh = self.file.open(self._mode)
#    1357 # the file should restart the file-read (as per instructed)
#    1358 self._line = 0
#
# File ~/.local/share/uv/python/cpython-3.13.7-linux-x86_64-gnu/lib/python3.13/pathlib/_local.py:537, in Path.open(self, mode, buffering, encoding, errors, newline)
#     535 if "b" not in mode:
#     536     encoding = io.text_encoding(encoding)
# --> 537 return io.open(self, mode, buffering, encoding, errors, newline)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Graphene/siesta.fdf'

# %%
band_pz = sisl.BandStructure(Ham0,points= [[0., 0., 0.], [1 / 3, 2 / 3, 0], [0, 0.5, 0],[0., 0., 0.]],divisions= 300, names=[r'$G$', r"$K$", r"$M$",r'$G$'])
band = sisl.BandStructure(H0_DFT,points= [[0., 0., 0.], [1 / 3, 2 / 3, 0], [0, 0.5, 0],[0., 0., 0.]],divisions= 300, names=[r'$G$', r"$K$", r"$M$",r'$G$'])

# %%
fig = plt.figure('Bands')
ax = fig.add_subplot(111)
       
lk, kt, kl = band.lineark(True)
ax.set_ylabel(r'$E-E_F$')
bs = []
for ik, eigh in enumerate(band.apply.eigh()):
    bs.append(eigh)
bs= np.array(bs)
        
ax.set_ylim(-15,15)
firsttime=True
    
for bk in bs.T:
    if(firsttime):
        ax.plot(lk, bk, c='k', label='DFT')
        firsttime=False
    else:
        ax.plot(lk, bk, c='k')

bs = []
for ik, eigh in enumerate(band_pz.apply.eigh()):
    bs.append(eigh)
bs= np.array(bs)

firsttime=True
    
for bk in bs.T:
    if(firsttime):
        ax.plot(lk, bk, c='r', label=r'$TB$')
        firsttime=False
    else:
        ax.plot(lk, bk, c='r')
ax.hlines(y=0,xmin=0,xmax=10,color='k',lw=0.1)
                
xcoords = kt
for k in xcoords:
    plt.axvline(x=k,c='k',lw=0.1)        
plt.xticks(kt, kl)        
ax.legend(loc='center right')
ax.set_xlim(kt[0],kt[-1])
# Out:
# (0.0, 3.9985980682436026)

# %% [markdown]
# # Generate Files for TBT

# %%
view(Ham0.to.ase())
# Out:
# <Popen: returncode: None args: ['/home/alan/ase_sisl_project/bin/python3', '...>

# %%
Ham=Ham0.tile(1,0).tile(1,1)
print(Ham.nsc)
# Out:
# [3 3 1]

# %%
# Number of repetitions in a,b 
N0 = 12
N1 = 12
nk1 = int(np.ceil(1000/N1))
eta = 0.001* 1j
rse = sisl.RealSpaceSE(Ham, 0, 1, (N0, N1, 1))
rse.setup(eta= 0.001, bz=sisl.MonkhorstPack(Ham, [1, nk1, 1]))

# %%
# Electrode
H_elec, elec_indices=rse.real_space_coupling(ret_indices=True)
#H_elec.write(HOME_DIR+'TBT/Elec.nc')

# %%
# Device Hamiltonian
# equivakent to H = rse.real_space_parent()
HamNN=Ham.tile(N0,0).tile(N1,1)
HamNN.set_nsc([1,1,1])
geomNN = HamNN.geometry

# Get indices inside atoms and elec atoms
all_atoms=np.arange(0,HamNN.na)
inside_atoms = np.delete(all_atoms, elec_indices)
Haminside=HamNN.sub(inside_atoms)
HamSE=HamNN.sub(elec_indices)

# reorder indixes
alist = np.concatenate([elec_indices, inside_atoms])
HamNN_reorder=HamNN.sub(alist)
HamNN_reorder.set_nsc([1,1,1])
#HamNN_reorder.write(HOME_DIR+'TBT/Device.nc')

# %%
fig, ax = plt.subplots(figsize=(8,8))
ax.set_aspect('equal')
for i in np.arange(0,HamNN_reorder.na):
    if i < HamSE.na:
        ax.text(HamNN_reorder.xyz[i,0],HamNN_reorder.xyz[i,1],i,c='k')
        plt.scatter(HamNN_reorder.xyz[i,0],HamNN_reorder.geometry.xyz[i,1],c='b',s=10,label='Elec')
    else:
        plt.scatter(HamNN_reorder.xyz[i,0],HamNN_reorder.geometry.xyz[i,1],c='gray',s=10,label='Dev')
for idx in np.arange(Ham.geometry.na):
    ax.scatter(Ham.geometry.xyz[idx,0],Ham.geometry.xyz[idx,1],c='red',s=100,edgecolors='k',linewidths=1)

# %%
dE=0.01
Emin, Emax = -3.0, 3.0
E = np.arange(Emin, Emax + dE / 2, dE)
#sisl.io.tableSile(HOME_DIR+"TBT/contour.E", 'w').write_data(E, np.zeros(E.size) + dE)

# %%
bz = sisl.BrillouinZone(H_elec)

# %%
### Now write the GF file as input to TBT
eta = 0.001* 1j
t0 = time.perf_counter()

with sisl.io.tbtgfSileTBtrans(HOME_DIR+"TBT/graphene.TBTGF") as f:
   f.write_header(bz, E+ eta )
   for ispin, new_k, k, e in f:
        if new_k:
            H = H_elec.Hk(format='array', dtype=np.complex128)
            S = H_elec.Sk(format='array', dtype=np.complex128)
            f.write_hamiltonian(H, S)
        RSE = rse.self_energy(e + eta,bulk=True, coupling=True)
        #RSE_reordered = RSE[np.ix_(alist, alist)]
        f.write_self_energy(RSE)
t1 = time.perf_counter()
print(f"Total runtime: {t1 - t0:.2f} seconds")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[12], line 12
#      10     S = H_elec.Sk(format='array', dtype=np.complex128)
#      11     f.write_hamiltonian(H, S)
# ---> 12 RSE = rse.self_energy(e + eta,bulk=True, coupling=True)
#      13 #RSE_reordered = RSE[np.ix_(alist, alist)]
#      14 f.write_self_energy(RSE)
#
# File ~/projects/QTM-ML/.venv/lib/python3.13/site-packages/sisl/physics/self_energy.py:1051, in RealSpaceSE.self_energy(self, E, k, bulk, coupling, dtype, **kwargs)
#    1048     E = E.real + 1j * self._options["eta"]
#    1050 # Calculate the real-space Green function
# -> 1051 G = self.green(E, k, dtype=dtype)
#    1053 if coupling:
#    1054     orbs = self._calc["orbs"]
#
# File ~/projects/QTM-ML/.venv/lib/python3.13/site-packages/sisl/physics/self_energy.py:1323, in RealSpaceSE.green(self, E, k, dtype, apply_kwargs, **kwargs)
#    1320 no = len(self.parent)
#    1322 # calculate the Green function
# -> 1323 G = bz.apply.renew(**apply_kwargs).average(_func_bloch)(
#    1324     dtype=dtype, no=no, tile=tile, idx0=idx0
#    1325 )
#    1326 if not bloch.finalize:
#    1327     bloch.unfold_finalize(G)
#
# File ~/projects/QTM-ML/.venv/lib/python3.13/site-packages/sisl/physics/_brillouinzone_apply.py:458, in AverageApply.dispatch.<locals>.func(wrap, eta, *args, **kwargs)
#     453 eta.update()
#     454 for i, ki in enumerate(k[1:], 1):
#     455     v += (
#     456         _asoplist(
#     457             wrap(
# --> 458                 method(*args, k=ki, **kwargs),
#     459                 parent=parent,
#     460                 k=ki,
#     461                 weight=w[i],
#     462             )
#     463         )
#     464         * w[i]
#     465     )
#     466     eta.update()
#     467 eta.close()
#
# File ~/projects/QTM-ML/.venv/lib/python3.13/site-packages/sisl/physics/self_energy.py:1313, in RealSpaceSE.green.<locals>._func_bloch(k, dtype, no, tile, idx0)
#    1312 def _func_bloch(k, dtype, no, tile, idx0):
# -> 1313     return bloch(_calc_green, k, dtype=dtype, no=no, tile=tile, idx0=idx0)
#
# File ~/projects/QTM-ML/.venv/lib/python3.13/site-packages/sisl/physics/bloch.py:197, in Bloch.__call__(self, func, k, *args, **kwargs)
#     195 del M0
#     196 for i in range(1, K_unfold.shape[0]):
# --> 197     M[i] = func(*args, k=K_unfold[i, :], **kwargs)
#     198 return bloch_unfold(self._bloch, K_unfold, M, self.finalize)
#
# File ~/projects/QTM-ML/.venv/lib/python3.13/site-packages/sisl/physics/self_energy.py:1224, in RealSpaceSE.green.<locals>._calc_green(k, dtype, no, tile, idx0)
#    1222 def _calc_green(k, dtype, no, tile, idx0):
#    1223     # Calculate left/right self-energies
# -> 1224     Gf, A2 = SE(
#    1225         E, k, dtype=dtype, bulk=True, **kwargs
#    1226     )  # A1 == Gf, because of memory usage
#    1227     # skip negation since we don't do negation on tY/tX
#    1228     B = M1Pk(k, dtype=dtype, format="array", **kwargs)
#
# File ~/projects/QTM-ML/.venv/lib/python3.13/site-packages/sisl/messages.py:107, in deprecate_argument.<locals>.deco.<locals>.wrapped(*args, **kwargs)
#     105     if new is not None:
#     106         kwargs[new] = kwargs.pop(old)
# --> 107 return func(*args, **kwargs)
#
# File ~/projects/QTM-ML/.venv/lib/python3.13/site-packages/sisl/physics/self_energy.py:665, in RecursiveSI.self_energy_lr(self, E, k, dtype, atol, bulk, **kwargs)
#     660 if info != 0:
#     661     raise ValueError(
#     662         f"{self.__class__.__name__}.self_energy_lr could not solve G x = B system!"
#     663     )
# --> 665 matmul(alpha, tab[:, 1, :], out=tmp)
#     666 # Update bulk Green function
#     667 subtract(GB, tmp, out=GB)
#
# KeyboardInterrupt:

# %%
f = open(HOME_DIR+"TBT/tbt.fdf", 'w')
f.write(
"""
SystemName        graphene
SystemLabel       graphene

# ---------- Hamiltonian ----------
TBT.HS Device.nc

#---------- Electrode ----------
# %block TS.Elecs
    Elec
# %endblock TS.Elecs

# %block TS.Elec.Elec
    HS Elec.nc
    semi-inf-direction  abc 
    electrode-position 1
    Out-of-core true
    tbt.Gf      graphene.TBTGF
# %endblock 

# ---------- k-point sampling ----------
TBT.k [1 1 1]

# ---------- Contour line ----------
# %block TBT.Contour.line
  part line
     from -3 eV to 3 eV
       file contour.E 
# %endblock TBT.Contour.line

# ---------- Output ----------
TBT.DOS.A
TBT.DOS.Gf
TBT.Current.Orb
"""
       )
f.close()

# %% [markdown]
# # Calculation in sisl

# %%
Ham=Ham0.tile(1,0).tile(1,1)
print(Ham.nsc)
geomNN=Ham.geometry
# Out:
# [3 3 1]

# %%
# Energy contour
eta = 0.001* 1j
dE=0.1
Emin, Emax = -3.0, 3.0
energies = np.arange(Emin, Emax + dE / 2, dE)
energies = np.array([dE*i for i in range(2,3)])

# Real Space Self Energies
N0 = 12
N1 = 12
nk1 = int(np.ceil(3*900/N1))

rse = sisl.RealSpaceSE(Ham, 0, 1, (N0, N1, 1))
rse.setup(eta= 1e-3, bz=sisl.MonkhorstPack(Ham, [1, nk1, 1]))
elec_indices = rse.real_space_coupling(geomNN)[1]
nC = len(elec_indices)   # number of coupling atoms

# Hamiltonian Self Energy
HamNN=Ham.tile(N0,0).tile(N1,1)
geomNN = HamNN.geometry
HamNN.set_nsc([1,1,1]) # remove al pbc
geomNN = HamNN.geometry

# indexes sort
all_atoms=np.arange(0,HamNN.na)
inside_atoms = np.delete(all_atoms, elec_indices, axis=0)
alist = np.concatenate([elec_indices, inside_atoms])

# Reordering Hamiltonain
HamNN_reorder=HamNN.sub(alist)
HamNN_reorder.reduce()
HamNN_reorder.set_nsc([1,1,1]) # remove al pbc
H_sub = HamNN_reorder.Hk(format="array")   
S_sub= HamNN_reorder.Sk(format="array")

# %%
t0 = time.perf_counter()
LDOS=loop_GF(energies,eta,rse,H_sub,S_sub,alist=alist)
t1 = time.perf_counter()
print(f"Total runtime: {t1 - t0:.2f} seconds")
print(f"Time per energy: {(t1 - t0)/len(energies):.4f} s")
LDOS_dev= LDOS[nC:,:]
DOS_dev = LDOS_dev.sum(axis=0)
# Out:
# DOS: 100%|██████████| 1/1 [00:00<00:00,  1.00it/s]
# Total runtime: 1.00 seconds
# Time per energy: 0.9989 s

# %% [markdown]
# # Plotting

# %%
#tbt = sisl.get_sile('TBT/graphene.TBT.nc')

# %%
# === plot DOS ===
E_idx=30
plt.figure(figsize=(6,4))
#plt.plot(tbt.E, tbt.DOS(), lw=1.5,c='r',label='TBT')
plt.plot(energies,DOS_dev,c='k',label='sisl')
plt.xlabel("Energy (eV)")
plt.ylabel("DOS (states / eV)")
plt.vlines(x=energies[E_idx],ymin=0,ymax=600,color='k',linestyle='dashed')
plt.ylim(0,80)
plt.xlim(-3,3)
plt.legend()
plt.show()

# %%
fig, ax = plt.subplots(figsize=(6,6))
E_idx=30
scale=500000
ax.set_aspect('equal')
for i in np.arange(0,HamNN_reorder.na):
    if i < HamSE.na:
        ax.scatter(HamNN_reorder.xyz[i,0],HamNN_reorder.geometry.xyz[i,1],c='r',s=scale*LDOS.T[E_idx][i],edgecolors='k',lw=0.1)
    else:
        ax.scatter(HamNN_reorder.xyz[i,0],HamNN_reorder.geometry.xyz[i,1],c='gray',edgecolors='k',s=scale*LDOS.T[E_idx][i],lw=0.1)

# %%
def calc_RSE(E,eta,rse,H_sub,S_sub,alist=None):
    z = E +  eta
    RSE = rse.self_energy(z)
    if alist is not None:
        RSE = RSE[np.ix_(alist, alist)]
    return RSE

# %%
eta=0.001j

# %%
E = 0.0
component="real"

SE = calc_RSE(E, eta, rse, H_sub, S_sub, alist)

xyz = HamNN_reorder.geometry.xyz
x, y, z = xyz[:,0], xyz[:,1], xyz[:,2]
diag = np.real(SE.diagonal()) if component == "real" else np.imag(SE.diagonal())
print(max(diag),min(diag))

fig=plt.figure()
ax = fig.add_subplot()
ax.set_aspect('equal')

for i in np.arange(0,HamNN_reorder.na):
    sc=ax.scatter(x[i], y[i], c=diag[i],vmax=1000,vmin=-1000,cmap='RdBu')
plt.colorbar(sc, ax=ax)

plt.tight_layout()
plt.show()
# Out:
# 7.0666557423888855e-12 -1.2457440592776011e-11

# %%
diag = np.abs(SE.diagonal()) 
print(max(diag),min(diag))

fig=plt.figure()
ax = fig.add_subplot()
ax.set_aspect('equal')

for i in np.arange(0,HamNN_reorder.na):
    sc=ax.scatter(x[i], y[i], c=diag[i],vmax=1000,vmin=0,cmap='viridis')
plt.colorbar(sc, ax=ax)

plt.tight_layout()
plt.show()
# Out:
# 2608.900407774883 2.295368340867658e-19

# %%
plt.scatter(alist,np.imag(SE).diagonal(),label='imag')
plt.scatter(alist,np.real(SE).diagonal(),label='real')
plt.xlabel('atom idx')
plt.ylabel('RSE')
plt.legend()

# %%
view(HamNN_reorder.to.ase())
# Out:
# <Popen: returncode: None args: ['/home/bastian/projects/QTM-ML/.venv/bin/pyt...>

# %%
plt.scatter(HamNN_reorder.xyz[:,0],np.imag(SE).diagonal(),label='imag')
plt.scatter(HamNN_reorder.xyz[:,0],np.real(SE).diagonal(),label='real')
plt.xlabel('x position')
plt.ylabel('RSE')
plt.legend()

# %%
plt.scatter(HamNN_reorder.xyz[:,1]-HamNN_reorder.geometry.center()[1],np.imag(SE).diagonal(),label='imag')
plt.scatter(HamNN_reorder.xyz[:,1]-HamNN_reorder.geometry.center()[1],np.real(SE).diagonal(),label='real')
plt.xlabel('y position')
plt.ylabel('RSE')
plt.legend()
